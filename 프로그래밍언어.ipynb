# %% [markdown]
# <a href="https://colab.research.google.com/github/shyun03/LEcture/blob/python-tester/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EC%96%B8%EC%96%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
score = 100
print(score)
# Out:
# 100

# %%
width = 10
height = 100
area = width * height
print(area)
# Out:
# 1000

# %%
text = "안녕하세요 !"
print(text)
# Out:
# 안녕하세요 !

# %%
type(text)
# Out:
# str

# %%
a = 10
b = a
a = 100
print(b)
# Out:
# 10
